# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /Users/claudiacarvalho/Data/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3464, 277)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.payment:account_cards  \
# 0              NaN               NaN         NaN                        NaN
# 1              NaN               NaN         NaN                        NaN
# 2              NaN               NaN         NaN                        NaN
# 3              NaN               NaN         NaN                        NaN
# 4              NaN               NaN         NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:seafood tags.recycling:low_energy_bulbs  \
# 0                     NaN               NaN                             NaN
# 1                     NaN               NaN                             NaN
# 2                     NaN               NaN                             NaN
# 3                     NaN               NaN                             NaN
# 4                     NaN               NaN                             NaN
#
#   tags.opening_hours:cafe tags.name:zh-Hans tags.panoramax
# 0                     NaN               NaN            NaN
# 1                     NaN               NaN            NaN
# 2                     NaN               NaN            NaN
# 3                     NaN               NaN            NaN
# 4                     NaN               NaN            NaN
#
# [5 rows x 277 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96e9cc038f5a9ed30b70a4a12bdfca4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96e9cc038f5a9ed30b70a4a12bdfca4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96e9cc038f5a9ed30b70a4a12bdfca4b = L.map(
#                 &quot;map_96e9cc038f5a9ed30b70a4a12bdfca4b&quot;,
#                 {
#                     center: [47.01062440107172, 8.006166859274527],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#
#
#
#             var tile_layer_660cadab72eb763ebadc11102ffb3af9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_660cadab72eb763ebadc11102ffb3af9.addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#             var marker_ca01230b83713bc69284397a825e57b5 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#         var popup_2e5f5f15eef003229f41428b5f280a85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a967de7ffd2c1197e3bf9decdd3b9b60 = $(`&lt;div id=&quot;html_a967de7ffd2c1197e3bf9decdd3b9b60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_2e5f5f15eef003229f41428b5f280a85.setContent(html_a967de7ffd2c1197e3bf9decdd3b9b60);
#
#
#
#         marker_ca01230b83713bc69284397a825e57b5.bindPopup(popup_2e5f5f15eef003229f41428b5f280a85)
#         ;
#
#
#
#
#             var marker_8b83441e69549a3dd2b4035e95450f35 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#         var popup_1a3af0dd7c85a74c16aada25f2382824 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bd3e04e9ba6bd749de69c4c6fb4eac2 = $(`&lt;div id=&quot;html_0bd3e04e9ba6bd749de69c4c6fb4eac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_1a3af0dd7c85a74c16aada25f2382824.setContent(html_0bd3e04e9ba6bd749de69c4c6fb4eac2);
#
#
#
#         marker_8b83441e69549a3dd2b4035e95450f35.bindPopup(popup_1a3af0dd7c85a74c16aada25f2382824)
#         ;
#
#
#
#
#             var marker_7709b2e497c7251d8e3e5d1d5b228182 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#         var popup_506808b3e065ce1c3fd28b849c0628bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cf278e7de174fe1c1997288f1df9ed8 = $(`&lt;div id=&quot;html_5cf278e7de174fe1c1997288f1df9ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_506808b3e065ce1c3fd28b849c0628bd.setContent(html_5cf278e7de174fe1c1997288f1df9ed8);
#
#
#
#         marker_7709b2e497c7251d8e3e5d1d5b228182.bindPopup(popup_506808b3e065ce1c3fd28b849c0628bd)
#         ;
#
#
#
#
#             var marker_2a3ba9ccdd59e054ffb2b69d809ea309 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#         var popup_6191184bfca2e5b5656aee020299874d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cb072ada8b64495528cf75fcaeadc8f = $(`&lt;div id=&quot;html_3cb072ada8b64495528cf75fcaeadc8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_6191184bfca2e5b5656aee020299874d.setContent(html_3cb072ada8b64495528cf75fcaeadc8f);
#
#
#
#         marker_2a3ba9ccdd59e054ffb2b69d809ea309.bindPopup(popup_6191184bfca2e5b5656aee020299874d)
#         ;
#
#
#
#
#             var marker_115583a4be543d72fc55e02a39b41b3b = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_96e9cc038f5a9ed30b70a4a12bdfca4b);
#
#
#         var popup_cd3194c189118eeeddf579e85239c037 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f56d3e00f7957fdc8b4c9c201bb4eb7 = $(`&lt;div id=&quot;html_5f56d3e00f7957fdc8b4c9c201bb4eb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_cd3194c189118eeeddf579e85239c037.setContent(html_5f56d3e00f7957fdc8b4c9c201bb4eb7);
#
#
#
#         marker_115583a4be543d72fc55e02a39b41b3b.bindPopup(popup_cd3194c189118eeeddf579e85239c037)
#         ;
#
#
#
#
#             var marker_1579eaa7ff0665e5b60873a93ca90c44 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 24.6.0
# Datetime: 2025-12-03 16:53:48
# Python Version: 3.14.0
# -----------------------------------
